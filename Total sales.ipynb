# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar
from datetime import datetime

# %%
# https://fred.stlouisfed.org/series/TOTALSA

vehicle_sales = pd.read_csv("Data_files/total_vehicle_sales.csv", index_col=0, parse_dates=True)
total_sales = vehicle_sales['Total sales']
total_sales
# Out:
# Date
# 2015-01-01    16.912
# 2015-02-01    16.895
# 2015-03-01    17.894
# 2015-04-01    17.689
# 2015-05-01    17.945
#                ...
# 2022-07-01    13.810
# 2022-08-01    13.740
# 2022-09-01    14.108
# 2022-10-01    15.613
# 2022-11-01    14.645
# Name: Total sales, Length: 95, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20, 8))

sns.lineplot(total_sales)

crisis_data = [
    (datetime(2020, 3, 1), "Start of coronavirus")
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, total_sales.asof(date)),
                xytext=(date, total_sales.asof(date)),
                arrowprops=dict(facecolor="black", headwidth=4, width=.6,
                                headlength=2),
                horizontalalignment="left", verticalalignment="top")

ax.set_title("\nTotal vehicle sales\n", fontsize=25)
ax.set_xlabel("\nDate", fontsize=20)
ax.set_ylabel("Sales (in millions)", fontsize=20)
ax.legend(["Sales"], title="Category", edgecolor="#1c1c1c")
sns.despine(left=True, bottom=True)

plt.show()
